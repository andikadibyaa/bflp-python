# %% [markdown]
# # Outline EDA dan Visualisasi Data
#
# 1. Import Library
# 2. Load Data
# 3. Pemahaman Data Awal
#    - Struktur data
#    - Statistik deskriptif
# 4. Data Cleaning
#    - Missing value
#    - Duplicate data
#    - Nilai aneh / outlier
# 5. Exploratory Data Analysis (EDA)
#    - Analisis univariate
#    - Analisis multivariate
#    - Ringkasan temuan
# 6. Visualisasi Data
#    - Distribusi data
#    - Korelasi antar variabel
#    - Visualisasi per kategori
#    - Insight dari visualisasi
# 7. Kesimpulan
