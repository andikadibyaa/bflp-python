# %%
# Data sederhana dengan dictionary

data = {
    "Nama": ["Andi", "Budi", "Citra", "Deni", "Eka", "Fajar","Gita","Hadi"],
    "Usia": [28, 42, 35, 55, 23, 47 , 31, 61],
    "Kota": ["Jakarta", "Bandung", "Jakarta", "Surabaya", "Bandung", "Medan", "Jakarta", "Surabaya"],
    "Gaji": [8000000, 15000000, 12000000, 4500000, 6000000, 11000000, 9500000000, 5000000],
}

import pandas as pd

df = pd.DataFrame(data)
print(df)

# Print rata - rata gaji
print("Rata-rata gaji:", df["Gaji"].mean())
# Out:
#     Nama  Usia      Kota        Gaji
# 0   Andi    28   Jakarta     8000000
# 1   Budi    42   Bandung    15000000
# 2  Citra    35   Jakarta    12000000
# 3   Deni    55  Surabaya     4500000
# 4    Eka    23   Bandung     6000000
# 5  Fajar    47     Medan    11000000
# 6   Gita    31   Jakarta  9500000000
# 7   Hadi    61  Surabaya     5000000
# Rata-rata gaji: 1195187500.0
